# %%
import audioop
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(data)

# %%
data = np.load('signal.npy')

# %%
data
# Out:
# array([111, 111, 111, ..., 212, 206,  74])

# %%
u_law = data
u_law = [chr(x) for x in u_law]
u_law = ''.join(u_law)
original = audioop.ulaw2lin(u_law, 2)

# %%
original
# Out:
# '|\xff|\xff|\xff|\xff|\xff|\xff\x90\xff\x90\xff\x90\xff\x90\xff\x98\xff\x90\xff\x98\xff\x98\xff\x98\xff\x98\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\xff|\\\xff\\\xff\\\xff\\\xff\\\xff\\\xffL\xffL\xffL\xffL\xffL\xffL\xffL\xffL\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xffl\xffL\xffL\xffL\xffL\xffL\xffL\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xffL\xffL\xffL\xffL\xffL\xffL\xffL\xffL\xff<\xff<\xff<\xffL\xff<\xff<\xff<\xff<\xff<\xff,\xff,\xff,\xff,\xff,\xff,\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff\x1c\xff,\xff,\xff,\xff,\xff,\xff,\xff\\\xff\\\xff\\\xff\\\xff\\\xffl\xffl\xffl\xff|\xff|\xff|\xff|\xff|\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xffl\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xff\\\xffl\xffl \x000\x000\x008\x008\x008\x008\x00 \x00 \x00\x18\x00\x18\x00\x18\x00\x18\x00\x10\x00\x10\x00\x18\x00\xf8\xff\xf8\xff\xf8\xff\xf8\xff\x00\x00\x08\x00\x18\x000\x000\x008\x008\x008\x00H\x00H\x00H\x008\x008\x00 \x00\x08\x00\x08\x00\x08\x00\xf0\xff\xf0\xff\x08\x00\x08\x00\x18\x00\x18\x00 \x000\x000\x000\x00H\x00P\x00h\x00h\x00h\x00h\x00p\x00p\x00p\x00p\x00p\x00X\x00P\x00P\x00P\x00P\x00@\x008\x008\x008\x008\x008\x008\x008\x008\x008\x00P\x00P\x00X\x00X\x00h\x00h\x00h\x00h\x00`\x00`\x00h\x00h\x00`\x00X\x00X\x00X\x00X\x00X\x00X\x00X\x00X\x00X\x00H\x00X\x00h\x00h\x00h\x00h\x00x\x00\x84\x00\x84\x00\x84\x00\x94\x00\x94\x00\x94\x00\x94\x00\x84\x00\x94\x00x\x00x\x00p\x00p\x00`\x00`\x00`\x00`\x00`\x00`\x00P\x00P\x00P\x00X\x00X\x00`\x00p\x00p\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00`\x00`\x00`\x00`\x00`\x00`\x00`\x00`\x00`\x00`\x00`\x00h\x00h\x00h\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00x\x00h\x00h\x00h\x00h\x00h\x00X\x00X\x00X\x00X\x00X\x00X\x00X\x00h\x00h\x00h\x00x\x00x\x00x\x00x\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84\x00\x84 ...

# %%
save_output(data, 'sample.wav')
# Out:
# output data size: 191998

# %%
import os, path
import glob
import numpy as np
import audioop
import wave

input_num_channels = 1
input_sample_rate = 48000
input_sample_width = 2

SAMPLE_RATE = 24000     # Output/test data sample rate
Q_FACTOR = 1            # Additional linear quantization (for testing only)
LIMIT = 20              # Number of files
MIN_DURATION = 4.0      # Minimum duration in seconds

def save_output(data, filename):
    # data is the u-law quantized sample
    u_law = data
    u_law = [chr(x) for x in u_law]
    u_law = ''.join(u_law)

    original = audioop.ulaw2lin(u_law, input_sample_width)
    print "output data size: " + str(len(original))

    output = wave.open(filename,'w')
    output.setparams((input_num_channels, input_sample_width, SAMPLE_RATE, 0, 'NONE', 'not compressed'))
    output.writeframes(original)
    output.close()

# %%
# %matplotlib inline
import seaborn
import numpy, scipy, matplotlib.pyplot as plt, pandas, librosa, IPython.display as ipd, urllib

# %%
x, fs = librosa.load('sample.wav', sr=44100)
ipd.Audio(x, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
